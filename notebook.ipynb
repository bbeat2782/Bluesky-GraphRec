# %%
import json
import matplotlib.pyplot as plt

fname = 'candidates_length.json'

# Load data from the JSON file
with open(fname, 'r') as f:
    candidates_length = json.load(f)

# Convert the dictionary values into a flat list of counts
all_counts = list(candidates_length.values())

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(all_counts, bins='auto', edgecolor='black')
plt.title("Distribution of Candidate Counts")
plt.xlabel("Number of Candidates")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Save the plot
output_path = "candidates_length_histogram.png"
plt.savefig(output_path)
plt.show()

# %%
import numpy as np
np.max(all_counts)
# Out:
# np.int64(9698)

# %%
np.median(all_counts)
# Out:
# np.float64(4257.0)
